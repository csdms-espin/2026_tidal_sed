# %% [markdown]
# # Tidal Flow Stuff

# %% [markdown]
# ## Import Landlab + Components + others

# %%
# landlab imports
from landlab import RasterModelGrid, imshow_grid
from landlab.components import TidalFlowCalculator
from landlab.plot.graph import plot_graph
from landlab.grid.mappers import map_link_vector_components_to_node, map_mean_of_link_nodes_to_link

# bmi imports
from bmi_topography import Topography

# other imports
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import Real Elevation Data and Create a Grid
#
# Documentation for bmi-topography can be found at https://bmi-topography.csdms.io/en/latest/#api-key
#
# Values for your south, north, west, and east values can be calculated at https://mapscaping.com/bounding-box-calculator/
#
# To access OpenTopography's elevation data, you will need to create an API key. Information for how to do this can be found at: https://opentopography.org/blog/introducing-api-keys-access-opentopography-global-datasets

# %%
# Import elevation data from OpenTopography -- this example is of Hog Island, VA
barrier_island_dem = Topography(
    dem_type = "SRTM15Plus", 
    south = 37.362517, 
    north = 37.473768, 
    west = -75.761307, 
    east = -75.623978, 
    api_key = '1b2170146e1f0fc9f60dadaf1447fe64')

barrier_island = barrier_island_dem.load()
barrier_island.values.shape
# Out:
# (1, 27, 33)

# %%
# Plot elevation as a check
import matplotlib.pyplot as plt
barrier_island_dem.da.plot(cmap="terrain")
plt.show()

# %% [markdown]
# RasterModelGrid() takes the parameter, xy_spacing, this is the resolution of your elevation data (SRTMGL3: 90 x 90 m, SRTM15Plus: 500 x 500 m, etc.)

# %%
# Input elevation data into grid
z = np.flipud(barrier_island.values.squeeze())
z = z.astype(float)
grid = RasterModelGrid(z.shape, xy_spacing=(500.0, 500.0))
grid.at_node["topographic__elevation"] = z

# %%
# set the tidal boundarys, where you want the water to come from
grid.set_closed_boundaries_at_grid_edges(False, True, True, True)

# %%
# Show grid
grid.imshow("topographic__elevation", cmap="terrain", vmin=-6) # vmin may need to be less than 0 if bathymetric data is loaded

# %% [markdown]
# ## Calculate cycle-averaged tidal flow
# The next section implements the landlab Tidal Flow component: https://landlab.readthedocs.io/en/latest/generated/api/landlab.components.tidal_flow.tidal_flow_calculator.html

# %%
# tidal parameters
tidal_range = 5
#tidal_
roughness = 0.01

# create instance
tfc = TidalFlowCalculator(grid, tidal_range=tidal_range, roughness=roughness)

# %%
# run model
tfc.run_one_step() 
# output:
# nodes: topographic elevation and mean water depth
# links: tidal flow velocity (ebb/flood)

# --> we need to use an incision component: e.g. fluvial incision?

# %%
# grid variables
grid.at_link.keys()
grid.at_node.keys()
# Out:
# ['topographic__elevation', 'mean_water__depth']

# %%
# check values at links of field flood tide velocity
grid.at_link["flood_tide_flow__velocity"][30]
# Out:
# np.float64(0.0)

# %%
# check values at links of field flood tide velocity
grid.at_link["ebb_tide_flow__velocity"]
# Out:
# array([-0., -0., -0., ..., -0., -0., -0.], shape=(1722,))

# %% [markdown]
# ## Ebb-Tide

# %%
# save the velocity information
ebb_vel_link = grid.at_link["ebb_tide_flow__velocity"]

# %%
# map links and nodes
ebb_vel_x, ebb_vel_y = map_link_vector_components_to_node(grid, ebb_vel_link)

# %%
# Get node coordinates
ebb_node_x = grid.node_x
ebb_node_y = grid.node_y

# %%
# test plot
# Plot using matplotlib quiver
grid.imshow("topographic__elevation", cmap="terrain", vmin=-6) # vmin may need to be less than 0 if bathymetric data is loaded
plt.quiver(ebb_node_x, ebb_node_y, ebb_vel_x, ebb_vel_y)
plt.xlabel("X Coordinate (m)")
plt.ylabel("Y Coordinate (m)")
plt.title("Flow Velocity Mapped from Links to Nodes")
plt.show()

# %% [markdown]
# ## Flood-Tide

# %%
# save the flood velocity information
from landlab.grid.mappers import map_link_vector_components_to_node
flood_vel_link = grid.at_link["flood_tide_flow__velocity"]

# %%
# map links and nodes
flood_vel_x, flood_vel_y = map_link_vector_components_to_node(grid, flood_vel_link)

# %%
# get node coordinates
flood_node_x = grid.node_x
flood_node_y = grid.node_y

# %%
# test plot using quiver
grid.imshow("topographic__elevation", cmap="terrain", vmin=-6)
plt.quiver(flood_node_x, flood_node_y, flood_vel_x, flood_vel_y)
plt.xlabel("X Coordinate (m)")
plt.ylabel("Y Coordinate (m)")
plt.title("Flow Velocity Mapped from Links to Nodes")
plt.show()

# %% [markdown]
# ## Writing a component for sediment transport

# %%
# 
def calc_deposition(w_s: float=0.03, c: float=0.1) -> float:
    """ compute deposition 
    
    PARAMETERS
    w_s: settling velocity
    c: sediment concentration"""
    return w_s*c

def calc_shear(grid,v):
    """ computes shear stress at links
    
    PARAMETERS
    w_s: settling velocity, default: fine sand 0.03 [m/s]
    c: sediment concentration, default: SSC in tidal water 0.1 [kg/m3]

    CONSTANTS
    n: Manning's n, default: 0.035
    rho_w: water density kg/m3
    g: gravity
    """
    
    rho_w = 1025
    g = 9.81
    n = 0.035 # mannings n for open water

    # water depth is transferred from nodes to links, v is on links
    shear=rho_w*g*(n**2)*(map_mean_of_link_nodes_to_link(grid, "mean_water__depth")**(-1/3))*np.sign(v)*(v**2)
    return shear

def calc_erosion(grid,v):
    """ compute erosion 
    
    PARAMETERS
    w_s: settling velocity
    c: sediment concentration

    rho_w: 1025 
    
    """
    shear_crit = 0.2 #[Pa]
    m_e = (10**-3) 

    erosion=m_e * np.sqrt((1+(calc_shear(grid,v)/shear_crit))**2)-1

    return erosion


def calc_bed_evolution(grid, mu: float=3.65, rslr=0):
    """
    calculates bed evolution

    PARAMETERS
    grid:
    mu: diffusion coefficient, default: 3.65 (Kirwan and Murray, 2007)
    rslr: relative sea level rise, default: 0

    DEPENDENCIES
    calc_deposition()
    calc_shear()
    calc_erosion()
    
    CONSTANTS
    #u: flow velocity
    #h: water depth
    rho_s: soil density =2650

    
    """
    rho_s=2650

    # deposition
    d = calc_deposition()
    # erosion
    e_plus = calc_erosion(grid, v=grid.at_link["flood_tide_flow__velocity"])
    e_min = calc_erosion(grid, v=grid.at_link["ebb_tide_flow__velocity"])
    e = (e_plus + e_min)/2
    e_at_nodes = grid.map_sum_of_inlinks_to_node(e) + grid.map_sum_of_outlinks_to_node(e)
    
    dz_dt = (
        grid.calc_flux_div_at_node(
            mu*grid.calc_grad_at_link(grid.at_node["topographic__elevation"])
        ) 
        + rslr 
        + ((d-e_at_nodes)/rho_s)
    )
    
    return dz_dt

# %%
## Plot results after one model run

# %%
# plot dz/dt
dz_dt = calc_bed_evolution(grid)

# %%
plt.title("Elevation after one tidal cycle")
z_new = (grid.at_node["topographic__elevation"]+dz_dt)
imshow_grid(grid,z_new,cmap="terrain", vmin=-6)

# %%
plt.title("Change in elevation")
imshow_grid(grid,dz_dt,cmap="Greens")

# %%
(grid.at_node["topographic__elevation"]+dz_dt)
# Out:
# array([-1.51356242e+00, -1.27157288e+00, -1.57673889e+00, -2.26502317e+00,
#        -3.30035942e+00, -3.93137234e+00, -3.78450173e+00, -4.21039861e+00,
#        -6.44559377e+00, -7.04671758e+00, -6.77463907e+00, -6.24703115e+00,
#        -5.45432370e+00, -4.40365546e+00, -3.51403516e+00, -3.06623071e+00,
#        -3.38702505e+00, -3.73471492e+00, -3.51681369e+00, -3.27943629e+00,
#        -3.77436488e+00, -4.39450162e+00, -5.06758683e+00, -5.84694665e+00,
#        -6.82379001e+00, -7.85778707e+00, -8.89367860e+00, -9.74363797e+00,
#        -1.02148723e+01, -1.03345708e+01, -1.04154996e+01, -1.05608949e+01,
#        -1.09236481e+01, -1.34173852e+00, -9.98552410e-01, -1.28999223e+00,
#        -1.99885258e+00, -4.22754819e+00, -5.99872804e+00, -4.85257175e+00,
#        -4.99867751e+00, -1.29982489e+01, -1.19934847e+01, -9.58357341e+00,
#        -7.99859302e+00, -6.68786223e+00, -4.99826680e+00, -3.33927218e+00,
#        -1.99831796e+00, -2.57367698e+00, -2.99821895e+00, -2.55389793e+00,
#        -1.99828465e+00, -3.99847428e+00, -4.77175622e+00, -5.36903426e+00,
#        -5.99831681e+00, -6.96178331e+00, -7.99842237e+00, -9.05498652e+00,
#        -9.99853108e+00, -1.01928327e+01, -9.99854738e+00, -1.00076046e+01,
#        -9.99840209e+00, -1.04663798e+01, -1.30420213e+00, -1.07500391e+00,
#        -1.44781208e+00, -2.24655816e+00, -3.43329490e+00, -4.44083088e+00,
#        -4.89607856e+00, -6.00461045e+00, -8.74596320e+00, -9.02927506e+00,
#         1.00109260e+00, -6.83388883e+00, -5.83659131e+00, -4.81943165e+00,
#        -3.87732477e+00, -3.30388848e+00, -3.29358773e+00, -3.40856829e+00,
#        -3.45711413e+00, -3.61105812e+00, -4.30442907e+00, -5.05667999e+00,
#        -5.78576025e+00, -6.52140755e+00, -7.29813452e+00, -8.15390696e+00,
#        -9.06465305e+00, -9.87755502e+00, -1.03115947e+01, -1.03893321e+01,
#        -1.02228100e+01, -1.00388502e+01, -1.01541621e+01, -1.28453487e+00,
#        -9.98313087e-01, -1.35259122e+00, -1.99858652e+00, -2.41820142e+00,
#        -2.99863801e+00, -3.86332874e+00,  1.00131780e+00,  1.00124967e+00,
#        -5.82277723e+00,  1.00140736e+00,  2.00126133e+00, -4.13069453e+00,
#        -3.99803405e+00, -3.78284731e+00, -3.99839423e+00, -3.94231279e+00,
#        -3.99889291e+00, -4.45400777e+00, -4.99822446e+00, -4.99825170e+00,
#        -5.59825483e+00, -6.28468018e+00, -6.99833184e+00, -7.45001582e+00,
#        -7.99846962e+00, -9.00937419e+00, -9.99829167e+00, -1.06551363e+01,
#        -1.09984125e+01, -1.05509367e+01, -9.99831034e+00, -9.99655684e+00,
#        -1.40552085e+00, -9.98630528e-01, -9.83104357e-01, -9.98657132e-01,
#        -1.48485487e+00, -2.33000964e+00, -3.04864902e+00,  1.47024833e-03,
#         1.45222620e-03, -3.38866561e+00,  1.44328140e-03,  1.00146042e+00,
#        -1.42628856e+00, -9.98094232e-01, -1.99908871e+00, -2.99805461e+00,
#        -4.04061524e+00, -4.99841595e+00, -4.95711276e+00, -4.99843258e+00,
#        -5.99837387e+00, -6.30571489e+00, -6.62082894e+00, -6.99822009e+00,
#        -7.42906543e+00, -7.99848838e+00, -8.97126554e+00, -9.99831001e+00,
#        -1.06688691e+01, -1.09985912e+01, -1.10001961e+01, -1.09984389e+01,
#        -1.09118966e+01, -1.74153524e+00, -1.42603322e+00, -1.46478203e+00,
#        -1.62657308e+00, -1.94357292e+00, -2.42697185e+00, -2.76783140e+00,
#         1.45833283e-03,  1.49531627e-03,  1.37428619e-03, -1.70576785e+00,
#         1.00143283e+00,  1.00142197e+00, -8.02645706e-01, -1.61358391e+00,
#        -2.61394655e+00, -3.65856089e+00, -4.56221117e+00, -5.01955365e+00,
#        -5.46514622e+00, -6.14384873e+00, -6.50343195e+00, -6.76978866e+00,
#        -7.05610366e+00, -7.41921059e+00, -7.96362138e+00, -8.78926425e+00,
#        -9.69761836e+00, -1.04185724e+01, -1.07772524e+01, -1.09523786e+01,
#        -1.10721789e+01, -1.11386554e+01, -2.23553174e+00, -2.02445423e+00,
#        -2.23424596e+00, -2.52635604e+00, -2.77142030e+00, -2.96140730e+00,
#        -2.94950070e+00,  1.45570455e-03,  1.49333527e-03, -1.56418822e+00,
#        -1.07121532e+00,  1.48552835e-03,  1.00142318e+00, -6.36391416e-01,
#        -1.40396064e+00, -2.31527830e+00, -3.31493658e+00, -4.24706952e+00,
#        -4.85114620e+00, -5.46378404e+00, -6.24660173e+00, -6.58879693e+00,
#        -6.82032550e+00, -7.02656709e+00, -7.20289784e+00, -7.55944904e+00,
#        -8.40564406e+00, -9.37388005e+00, -1.01818503e+01, -1.04920914e+01,
#        -1.07770540e+01, -1.10557325e+01, -1.13022400e+01, -2.88275092e+00,
#        -2.87504725e+00, -3.18629201e+00, -3.60997286e+00, -3.93181795e+00,
#        -3.78909715e+00, -3.44774406e+00,  1.41694560e-03,  1.00138061e+00,
#        -1.76421381e+00, -9.98109234e-01, -5.37245081e-01,  1.00144983e+00,
#         1.00137339e+00, -1.24768598e+00, -1.99838080e+00, -2.99773874e+00,
#        -3.99862039e+00, -4.50644544e+00, -4.99861887e+00, -5.99844123e+00,
#        -6.50335809e+00, -6.78257922e+00, -6.99798590e+00, -6.89653200e+00,
#        -6.99829368e+00, -7.93232839e+00, -8.99838722e+00, -9.77331547e+00,
#        -9.99838656e+00, -1.04991973e+01, -1.09983669e+01, -1.14683498e+01,
#        -3.54399246e+00, -3.66670996e+00, -4.07911121e+00, -4.60600922e+00,
#        -5.08861676e+00, -4.59338842e+00, -4.00627612e+00, -3.43305128e+00,
#        -2.88612992e+00, -2.35864146e+00, -1.47870830e+00, -8.28260699e-01,
#         1.00144150e+00,  1.00145362e+00,  2.00136789e+00, -1.81005563e+00,
#        -2.56351132e+00, -3.37901429e+00, -4.26444541e+00, -5.21614014e+00,
#        -6.20841034e+00, -6.44334228e+00, -6.48425933e+00, -6.49455941e+00,
#        -6.55102706e+00, -6.73768598e+00, -7.62965660e+00, -8.67737771e+00,
#        -9.73504256e+00, -1.01244048e+01, -1.03415710e+01, -1.05793018e+01,
#        -1.09639914e+01, -4.20619672e+00, -4.47930466e+00, -4.77984325e+00,
#        -5.08562476e+00, -5.24063604e+00, -4.90329723e+00, -4.36874145e+00,
#        -3.76555621e+00, -3.12913932e+00, -2.45022636e+00, -1.67479271e+00,
#        -9.98425364e-01, -7.21339190e-01, -9.98426507e-01,  1.00150498e+00,
#         3.00131929e+00, -2.18465430e+00, -2.99838942e+00, -3.90328131e+00,
#        -4.99849701e+00, -5.99847038e+00, -6.15206208e+00, -6.08554861e+00,
#        -5.99835009e+00, -6.40079529e+00, -6.99815934e+00, -7.35278048e+00,
#        -7.99815734e+00, -9.13988549e+00, -9.99825467e+00, -1.00227201e+01,
#        -9.99828972e+00, -1.04922228e+01, -4.76150125e+00, -5.15974669e+00,
#        -5.32247614e+00, -5.41902823e+00, -5.35122114e+00, -5.12657410e+00,
#        -4.67829931e+00, -4.08095116e+00, -3.37344379e+00, -2.58130273e+00,
#        -1.92757662e+00, -1.32638050e+00, -9.27181679e-01,  1.46517658e-03,
#         1.55161594e-03,  2.00141881e+00, -1.51085443e+00, -1.99843429e+00,
#        -2.94747578e+00, -3.99839750e+00, -4.99852197e+00, -5.53526113e+00,
#        -5.81023893e+00, -5.99835168e+00, -5.96732476e+00, -5.99822143e+00,
#        -6.45134567e+00, -6.99820243e+00, -8.11620238e+00, -8.99830972e+00,
#        -9.54892242e+00, -9.99843798e+00, -1.04774702e+01, -5.10198110e+00,
#        -5.49407027e+00, -5.71408158e+00, -5.81266373e+00, -5.75409978e+00,
#        -5.51977880e+00, -5.09145136e+00, -4.50851266e+00, -3.80684983e+00,
#        -3.03442401e+00, -2.31419300e+00, -1.65221309e+00, -1.15709033e+00,
#        -9.98465353e-01,  1.49459213e-03,  1.00152190e+00,  3.00132638e+00,
#        -9.98076427e-01, -2.09221389e+00, -3.29464360e+00, -4.41206122e+00,
#        -5.06801563e+00, -5.41828768e+00, -5.62199020e+00, -5.73078615e+00,
#        -5.90798630e+00, -6.29041378e+00, -6.86096664e+00, -7.67312398e+00,
#        -8.47128431e+00, -9.14217128e+00, -9.75176475e+00, -1.03664719e+01,
#        -5.34788268e+00, -5.77776998e+00, -6.07922128e+00, -6.26683831e+00,
#        -6.28927265e+00, -6.05150041e+00, -5.62247955e+00, -5.05321264e+00,
#        -4.36834203e+00, -3.58914325e+00, -2.77105677e+00, -1.97287641e+00,
#        -1.33900720e+00, -1.07542834e+00, -9.89184168e-01,  1.52379213e-03,
#         1.00153826e+00,  3.00134867e+00, -1.98420796e+00, -2.99817931e+00,
#        -4.32760725e+00, -4.89947777e+00, -5.15581043e+00, -5.32349238e+00,
#        -5.42903305e+00, -5.61195728e+00, -5.98581682e+00, -6.54202419e+00,
#        -7.30836214e+00, -8.14467844e+00, -8.81149752e+00, -9.45761708e+00,
#        -1.02257019e+01, -5.53328412e+00, -6.03319074e+00, -6.42099155e+00,
#        -6.74088070e+00, -6.90240303e+00, -6.65617711e+00, -6.22623463e+00,
#        -5.68378274e+00, -5.03327116e+00, -4.24510661e+00, -3.31828445e+00,
#        -2.33909651e+00, -1.50527098e+00, -1.28268428e+00, -1.24410703e+00,
#         1.49087039e-03,  1.58205660e-03,  3.00145066e+00,  4.00128229e+00,
#        -3.54427154e+00, -4.99797860e+00, -4.91673790e+00, -4.87578141e+00,
#        -4.99814621e+00, -4.95493035e+00, -4.99843703e+00, -5.43375781e+00,
#        -5.99842242e+00, -6.91581492e+00, -7.99852497e+00, -8.48947493e+00,
#        -8.99837961e+00, -9.98703623e+00, -5.62680858e+00, -6.13895131e+00,
#        -6.66034598e+00, -7.12830344e+00, -7.40213054e+00, -7.21225584e+00,
#         2.00123981e+00,  2.00126851e+00, -5.78844847e+00, -5.05755711e+00,
#        -4.01913188e+00, -2.89116628e+00, -1.96747596e+00, -1.68543812e+00,
#        -1.66185269e+00,  1.49937120e-03,  1.00146526e+00,  1.00156746e+00,
#         3.00139567e+00, -2.76443124e+00, -3.36690872e+00, -3.59826744e+00,
#        -3.80719575e+00, -4.04620914e+00, -4.32113367e+00, -4.65144545e+00,
#        -5.06315576e+00, -5.62058444e+00, -6.40967132e+00, -7.35165399e+00,
#        -8.00286262e+00, -8.65230787e+00, -9.58780904e+00, -5.68454259e+00,
#        -6.18721257e+00, -6.82347179e+00, -7.43494115e+00, -7.88390177e+00,
#        -7.67721348e+00,  1.00139695e+00,  1.00141339e+00, -6.55120697e+00,
#        -5.97242318e+00, -4.81512381e+00, -3.52838778e+00, -2.42049697e+00,
#        -2.19357137e+00, -2.19776033e+00,  1.43517099e-03,  1.53825660e-03,
#         1.00149446e+00,  2.00150906e+00,  3.00139567e+00,  3.00134080e+00,
#        -2.15411194e+00, -2.65660306e+00, -2.99809034e+00, -3.50427073e+00,
#        -3.99862740e+00, -4.42854649e+00, -4.99861937e+00, -5.84257210e+00,
#        -6.99843707e+00, -7.51257936e+00, -7.99844322e+00, -9.00473154e+00,
#        -5.77210134e+00, -6.29638130e+00, -6.91628271e+00, -7.51363228e+00,
#        -7.92488244e+00, -7.84874572e+00,  1.00125325e+00,  1.00126529e+00,
#        -7.13453218e+00, -6.67980796e+00, -5.58514307e+00, -4.33675511e+00,
#        -3.30794846e+00, -2.93758345e+00, -2.85330604e+00, -2.85977439e+00,
#         1.48188077e-03,  1.55285660e-03,  1.00152366e+00,  2.00150906e+00,
#         3.00149446e+00,  3.00138999e+00, -1.99811679e+00, -2.43444773e+00,
#        -2.76419276e+00, -2.99868121e+00, -3.49344032e+00, -3.99851896e+00,
#        -4.89021870e+00, -5.99862908e+00, -6.99719362e+00, -7.99857940e+00,
#        -8.51166481e+00, -5.85368102e+00, -6.35438151e+00, -6.92814485e+00,
#        -7.47226299e+00, -7.88486632e+00, -7.81926354e+00, -7.66885325e+00,
#        -7.55862010e+00, -7.49548206e+00, -7.31984262e+00, -6.23716244e+00,
#        -5.06860610e+00, -4.07421098e+00, -3.68042845e+00, -3.50587018e+00,
#        -3.44229982e+00,  1.00136129e+00,  1.00149446e+00,  1.00150895e+00,
#         1.00155276e+00,  3.00149446e+00,  5.00140686e+00,  5.00127808e+00,
#        -1.81873846e+00, -2.36728982e+00, -2.80952916e+00, -3.07318083e+00,
#        -3.43513419e+00, -4.05095334e+00, -4.98838904e+00, -6.02523894e+00,
#        -7.09549403e+00, -8.07788506e+00, -5.93537467e+00, -6.42518019e+00,
#        -6.85695848e+00, -7.23561137e+00, -7.50330893e+00, -7.50733601e+00,
#        -7.43714871e+00,  3.00102221e+00, -7.34479265e+00, -7.14637393e+00,
#        -6.46556635e+00, -5.66379897e+00, -4.93957125e+00,  1.00126747e+00,
#         1.00137243e+00, -3.84862558e+00, -3.67537003e+00,  1.00144070e+00,
#         1.00150840e+00,  1.00150793e+00,  2.00149446e+00,  2.00156746e+00,
#         3.00152366e+00,  3.00136520e+00, -2.03125357e+00, -2.34943784e+00,
#        -2.52366644e+00, -2.75691350e+00, -3.23187713e+00, -3.99906430e+00,
#        -4.99205856e+00, -6.15385571e+00, -7.55957888e+00, -5.95015233e+00,
#        -6.43077089e+00, -6.67269891e+00, -6.86760362e+00, -7.02767882e+00,
#        -7.02283912e+00, -6.99281127e+00,  1.00119658e+00, -6.97165170e+00,
#        -6.83796826e+00, -6.45975469e+00, -6.02012495e+00, -5.58273300e+00,
#        -4.92189523e+00,  1.00134491e+00,  1.00129533e+00, -3.85044189e+00,
#         1.00143768e+00,  1.00149257e+00,  1.56462137e-03,  1.00152237e+00,
#         2.00150906e+00,  3.00149446e+00,  3.00143810e+00, -1.85829364e+00,
#        -1.99832531e+00, -1.97395814e+00, -1.99847404e+00, -2.38430531e+00,
#        -2.99859874e+00, -3.91173688e+00, -4.99842646e+00, -6.98150512e+00,
#        -5.78227657e+00, -6.27554909e+00, -6.26090292e+00, -6.28577815e+00,
#        -6.40391803e+00, -6.36180164e+00, -6.37650625e+00, -6.43302671e+00,
#        -6.47618490e+00,  1.13908273e-03, -6.19505371e+00, -5.98600634e+00,
#        -5.84898306e+00, -4.98866681e+00, -4.31810691e+00, -3.93482580e+00,
#        -3.79972898e+00,  1.00137531e+00,  1.00144253e+00,  1.00148887e+00,
#         1.00151896e+00,  2.00150906e+00,  3.00149446e+00,  3.00144071e+00,
#        -1.67977373e+00, -1.39421310e+00, -1.61339919e+00, -1.75843739e+00,
#        -2.10052809e+00, -2.77913014e+00, -3.42981564e+00, -4.40961195e+00,
#        -6.26932236e+00, -5.20606225e+00, -5.42144186e+00, -5.37846318e+00,
#        -5.31445443e+00, -5.32728975e+00, -5.43975416e+00, -5.60548799e+00,
#        -5.76694854e+00, -5.86625861e+00, -5.82504021e+00, -5.54263087e+00,
#        -5.20172654e+00,  2.00111711e+00, -4.24387215e+00, -3.72290817e+00,
#        -3.37538829e+00, -3.20042757e+00, -3.18483362e+00, -3.26555312e+00,
#         1.00136676e+00,  1.00143668e+00,  2.00149439e+00,  3.00149446e+00,
#         3.00143459e+00, -2.09884957e+00, -1.99854072e+00, -2.10702146e+00,
#        -1.99854974e+00, -2.41038326e+00, -2.99834508e+00, -2.80538621e+00,
#        -2.99865034e+00, -5.36353070e+00, -4.45906251e+00, -4.44607493e+00,
#        -4.33891104e+00, -4.21587123e+00, -4.15348717e+00, -4.46555787e+00,
#        -4.80816225e+00, -5.07746579e+00, -5.22383363e+00, -5.16942761e+00,
#         1.00117928e+00, -4.09227236e+00, -3.54474321e+00,  1.00138069e+00,
#         2.00139628e+00,  2.00140135e+00,  1.00146041e+00,  1.00138179e+00,
#        -3.03894824e+00, -3.83860182e+00, -4.37563427e+00,  1.00150348e+00,
#         3.00147986e+00,  3.00136401e+00, -2.93312206e+00, -3.99847965e+00,
#        -3.94511301e+00, -3.99849259e+00, -3.17986271e+00, -2.99851824e+00,
#        -2.31668775e+00, -1.99870802e+00, -4.38202829e+00, -3.66805285e+00,
#        -3.42353298e+00, -3.37009538e+00, -3.30143738e+00, -3.27963586e+00,
#        -3.70025762e+00, -4.14322656e+00, -4.45416327e+00, -4.58206565e+00,
#        -4.43085839e+00, -3.77684942e+00,  1.37955877e-03,  1.00139985e+00,
#         1.00147602e+00,  1.00152280e+00,  1.00152206e+00,  1.00150746e+00,
#         1.00152279e+00,  2.00133188e+00, -4.07848156e+00, -4.99828475e+00,
#         3.00125986e+00,  3.00135401e+00, -9.98187847e-01, -2.27556083e+00,
#        -3.41031901e+00, -3.49362153e+00, -3.20615623e+00, -2.71493321e+00,
#        -2.63892546e+00, -2.61050625e+00, -2.96216961e+00, -4.31363986e+00,
#        -3.04291981e+00, -2.61073379e+00, -2.74291086e+00, -2.77226272e+00,
#        -2.68567557e+00, -3.26825271e+00, -3.72779623e+00, -3.98552020e+00,
#        -4.05161992e+00, -3.87656185e+00, -3.05904008e+00, -1.99575541e+00,
#        -9.31581574e-01, -1.24756899e+00,  1.00147484e+00,  1.00150678e+00,
#         1.00150650e+00,  1.00151937e+00,  2.00133916e+00, -3.59257384e+00,
#        -4.21951341e+00, -4.06702463e+00, -3.61845623e+00, -3.29173626e+00,
#        -3.43883549e+00, -3.72323053e+00, -3.13474785e+00, -2.54981835e+00,
#        -2.23324355e+00, -2.51927090e+00, -2.74347305e+00, -3.19216849e+00,
#        -4.39098934e+00, -2.86951917e+00, -2.68125557e+00, -2.81357630e+00,
#        -3.02975962e+00, -3.23897000e+00, -3.49549760e+00, -3.66278055e+00,
#        -3.68817751e+00, -3.55111840e+00, -3.21875366e+00,  1.40275563e-03,
#         1.46301717e-03,  1.00143703e+00,  1.51954302e-03,  1.00147816e+00,
#         1.00149080e+00,  1.00150093e+00,  1.00136045e+00, -3.01609863e+00,
#        -3.60792738e+00, -3.99832919e+00, -4.31787726e+00, -4.61495939e+00,
#        -4.99842247e+00, -3.97638276e+00, -2.99832033e+00, -2.44117260e+00,
#        -1.99832204e+00, -2.42406225e+00, -2.99843138e+00, -2.96788195e+00,
#        -2.99847427e+00, -4.92297287e+00, -2.80701826e+00, -2.83064907e+00,
#        -3.05845874e+00, -3.49608749e+00, -3.97809284e+00, -3.92703169e+00,
#        -3.78204363e+00, -3.55590480e+00, -3.22248619e+00, -2.78426545e+00,
#        -9.98867925e-01, -2.15493100e+00,  1.13207547e-03,  1.13207547e-03,
#         1.13207547e-03,  1.13207547e-03,  1.00113208e+00, -3.61651963e+00,
#        -3.71388810e+00, -4.01222127e+00, -4.41818851e+00, -4.24593347e+00,
#        -4.09763044e+00, -3.92272204e+00, -3.34255451e+00, -2.74383777e+00,
#        -2.34766453e+00, -2.34799116e+00, -3.13133758e+00, -3.89635509e+00,
#        -4.28519004e+00, -4.82523959e+00, -6.03047011e+00])
